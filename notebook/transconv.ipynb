# %%
import torch
import matplotlib.pyplot as plt

base = "/home/ir-rous1/rds/rds-ukaea-ap002-mOlK9qn0PlQ/ir-rous1/output/cnn-baseline/src/output_NEW/"

tasks = [
    "task_1-1", 
    "task_1-2", 
    "task_1-3",
    "task_2-1", 
    "task_2-2", 
    "task_2-3",
    "task_3-1", 
    "task_3-2", 
    "task_3-3",
    "task_4-1",
    "task_4-2",
    "task_4-3",
    "task_4-4",
    "task_4-5",
    ]

for task in tasks:

    plt.figure(figsize=(12, 5))
    print(task)
    
    for base in [
        # "/home/ir-rous1/rds/rds-ukaea-ap002-mOlK9qn0PlQ/ir-rous1/output/cnn-baseline/src/output_NEW_v1/", 
        #      "/home/ir-rous1/rds/rds-ukaea-ap002-mOlK9qn0PlQ/ir-rous1/output/cnn-baseline/src/output_NEW/",
            #  "/home/ir-rous1/rds/rds-ukaea-ap002-mOlK9qn0PlQ/ir-rous1/output/cnn-baseline/output_old/",
             "/home/ir-rous1/rds/rds-ukaea-ap002-mOlK9qn0PlQ/ir-rous1/output/cnn-baseline/"]: 

        for model_fill in ["",
                        # "_filled_RERUN", 
                        # "_filled_RERUN_monday_night", 
                        # "_filled_steps",
                        # "_filled", 
                        # "_filled_cutting_input"
                        ]:

            for model_v_path in [
                # f"cnn_model_b_32_w_16_lr_0.0001_D_16/{task}/model_v5{model_fill}/run_1/training_history.pt",
                # f"cnn_model_b_32_w_16_lr_0.0001_D_16/{task}/model_v5{model_fill}/run_2/training_history.pt",
                # f"cnn_model_b_32_w_8_lr_0.0001_D_16/{task}/model_v5{model_fill}/run_1/training_history.pt",
                # f"cnn_model_b_32_w_4_lr_0.0001_D_16/{task}/model_v5{model_fill}/run_1/training_history.pt",
                # f"cnn_model_b_32_w_4_lr_0.0001_D_16/{task}/model_v5{model_fill}/run_2/training_history.pt",
                # f"cnn_model_b_16_w_8_lr_0.0001_D_16/{task}/model_v5{model_fill}/run_1/training_history.pt",
                # f"cnn_model_b_16_w_4_lr_0.0001_D_16/{task}/model_v5{model_fill}/run_1/training_history.pt",
                # f"cnn_model_b_8_w_4_lr_0.0001_D_16/{task}/model_v5{model_fill}/run_1/training_history.pt",
                
                # f"cnn_model/{task}/model_v5{model_fill}/run_1/training_history.pt",
                f"output_old/cnn_model/{task}/training_history.pt",
                f"output/cnn_model/{task}/seed_200399/training_history.pt",
                f"output/cnn_model/{task}/seed_140801/training_history.pt",
                # f"output/cnn_model/{task}/seed_191299/training_history.pt",
                # f"cnn_model/{task}/seed_3/training_history.pt",
            ]:

                try:
                    data = torch.load(base + model_v_path, map_location="cpu")

                    model_name = model_v_path.split("/")[1]  # identify config

                    use_marker = 'o' if model_fill else None
                    num_epochs = len(data["train_loss"])

                    if num_epochs == 1:
                        # Only one epoch → scatter plot
                        continue
                        # plt.scatter(
                        #     [0],  # single epoch index
                        #     [data["train_loss"][0]],
                        #     label=f"train {model_v_path} ",
                        #     marker='o'
                        # )
                        # plt.scatter(
                        #     [0],
                        #     [data["val_loss"][0]],
                        #     label=f"val {model_v_path} ",
                        #     marker='o'
                        # )
                    else:
                        # Multiple epochs → line plot
                        plt.plot(
                            data["train_loss"],
                            label=f"train {model_v_path} ",
                            marker=use_marker
                        )
                        plt.plot(
                            data["val_loss"],
                            label=f"val {model_v_path} ",
                            marker=use_marker
                        )


                    print('train', task, model_v_path, min(data["train_loss"]))
                    print('val  ', task, model_v_path, min(data["val_loss"]))

                except Exception:
                    # print("skipping model", base + model_v_path)
                    continue

    plt.legend()
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# task_1-1
# train task_1-1 output_old/cnn_model/task_1-1/training_history.pt 0.10524109732661219
# val   task_1-1 output_old/cnn_model/task_1-1/training_history.pt 0.08500371620920721
# train task_1-1 output/cnn_model/task_1-1/seed_200399/training_history.pt 0.10682143062173549
# val   task_1-1 output/cnn_model/task_1-1/seed_200399/training_history.pt 0.08329121086513787
# train task_1-1 output/cnn_model/task_1-1/seed_140801/training_history.pt 0.1166325796178346
# val   task_1-1 output/cnn_model/task_1-1/seed_140801/training_history.pt 0.09385542363620185
# task_1-2
# train task_1-2 output_old/cnn_model/task_1-2/training_history.pt 0.003699548292944755
# val   task_1-2 output_old/cnn_model/task_1-2/training_history.pt 0.003256325383608439
# train task_1-2 output/cnn_model/task_1-2/seed_200399/training_history.pt 0.003802320264864635
# val   task_1-2 output/cnn_model/task_1-2/seed_200399/training_history.pt 0.0031950038834560116
# ...

# %%
import torch
import matplotlib.pyplot as plt

base = "/home/ir-rous1/rds/rds-ukaea-ap002-mOlK9qn0PlQ/ir-rous1/output/cnn-baseline/src/output_NEW_v1/"

tasks = [
    # "task_1-1", 
    # "task_1-2", 
    # "task_1-3",
    # "task_2-1", 
    # "task_2-2", 
    # "task_2-3",
    "task_3-1", 
    "task_3-2", 
    "task_3-3",
    # "task_4-1",
    # "task_4-2",
    # "task_4-3",
    # "task_4-4",
    # "task_4-5",
    ]


for task in tasks:

    plt.figure(figsize=(12, 5))
    print(task)

    for model_fill in ["",
                       "_filled_RERUN", 
                       "_filled_RERUN_monday_night", 
                    #    "_filled_steps",
                       "_filled" ]:

        for model_v_path in [
            f"cnn_model_b_32_w_16_lr_0.0001_D_16/{task}/model_v5{model_fill}/run_1/training_history.pt",
            f"cnn_model_b_32_w_16_lr_0.0001_D_16/{task}/model_v5{model_fill}/run_2/training_history.pt",
            f"cnn_model_b_32_w_8_lr_0.0001_D_16/{task}/model_v5{model_fill}/run_1/training_history.pt",
            f"cnn_model_b_32_w_4_lr_0.0001_D_16/{task}/model_v5{model_fill}/run_1/training_history.pt",
            f"cnn_model_b_32_w_4_lr_0.0001_D_16/{task}/model_v5{model_fill}/run_2/training_history.pt",
            f"cnn_model_b_16_w_8_lr_0.0001_D_16/{task}/model_v5{model_fill}/run_1/training_history.pt",
            f"cnn_model_b_16_w_4_lr_0.0001_D_16/{task}/model_v5{model_fill}/run_1/training_history.pt",
            f"cnn_model_b_8_w_4_lr_0.0001_D_16/{task}/model_v5{model_fill}/run_1/training_history.pt",
            f"cnn_model/{task}/model_v5{model_fill}/run_1/training_history.pt"
        ]:

            try:
                data = torch.load(base + model_v_path, map_location="cpu")

                model_name = model_v_path.split("/")[1]  # identify config

                use_marker = 'o' if model_fill else None
                num_epochs = len(data["train_loss"])

                if num_epochs == 1:
                    # Only one epoch → scatter plot
                    plt.scatter(
                        [0],  # single epoch index
                        [data["train_loss"][0]],
                        label=f"train {model_name} v5{model_fill}",
                        marker='o'
                    )
                    plt.scatter(
                        [0],
                        [data["val_loss"][0]],
                        label=f"val {model_name} v5{model_fill}",
                        marker='o'
                    )
                else:
                    # Multiple epochs → line plot
                    plt.plot(
                        data["train_loss"],
                        label=f"train {model_name} v5{model_fill}",
                        marker=use_marker
                    )
                    plt.plot(
                        data["val_loss"],
                        label=f"val {model_name} v5{model_fill}",
                        marker=use_marker
                    )


                print('train', task, f'v5{model_fill}', model_name, min(data["train_loss"]))
                print('val  ', task, f'v5{model_fill}', model_name, min(data["val_loss"]))

            except Exception:
                print("skipping model", base + model_v_path)
                continue

    plt.legend()
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# task_3-1
# skipping model /home/ir-rous1/rds/rds-ukaea-ap002-mOlK9qn0PlQ/ir-rous1/output/cnn-baseline/src/output_NEW_v1/cnn_model_b_32_w_16_lr_0.0001_D_16/task_3-1/model_v5/run_1/training_history.pt
# skipping model /home/ir-rous1/rds/rds-ukaea-ap002-mOlK9qn0PlQ/ir-rous1/output/cnn-baseline/src/output_NEW_v1/cnn_model_b_32_w_16_lr_0.0001_D_16/task_3-1/model_v5/run_2/training_history.pt
# skipping model /home/ir-rous1/rds/rds-ukaea-ap002-mOlK9qn0PlQ/ir-rous1/output/cnn-baseline/src/output_NEW_v1/cnn_model_b_32_w_8_lr_0.0001_D_16/task_3-1/model_v5/run_1/training_history.pt
# skipping model /home/ir-rous1/rds/rds-ukaea-ap002-mOlK9qn0PlQ/ir-rous1/output/cnn-baseline/src/output_NEW_v1/cnn_model_b_32_w_4_lr_0.0001_D_16/task_3-1/model_v5/run_1/training_history.pt
# skipping model /home/ir-rous1/rds/rds-ukaea-ap002-mOlK9qn0PlQ/ir-rous1/output/cnn-baseline/src/output_NEW_v1/cnn_model_b_32_w_4_lr_0.0001_D_16/task_3-1/model_v5/run_2/training_history.pt
# ...

# %%
#

# %%
#

# %%
#

# %%
#

# %%
#

# %%
# [ min(val, 20) for val in data["val_loss"] ]

# %%
# import torch
# import matplotlib.pyplot as plt

# base = "/home/ir-rous1/rds/rds-ukaea-ap002-mOlK9qn0PlQ/ir-rous1/output/cnn-baseline/src/output/"

# plt.figure(figsize=(8, 5))

# for task in ["task_1-1", "task_1-2", "task_1-3"]:

#     print(task)

#     for model_version in ["v3", "v4"]:
#         data = torch.load(
#             base + f"cnn_model_b_8_w_32_lr_00001/{task}/model_{model_version}/run_1/training_history.pt",
#             map_location="cpu"
#         )

#         plt.plot(data["train_loss"], label=f"{model_version} train")
#         plt.plot(data["val_loss"], label=f"{model_version} val")
#         # plt.plot([ min(val, 100) for val in data["val_loss"] ], label=f"{model_version} val")

#         print(task, model_version, min(data["val_loss"]))

#     # plt.ylim(0, 0.2)   # adjust these numbers
#     plt.xlabel("Epoch")
#     plt.ylabel("Loss")
#     plt.legend()
#     plt.grid(True)
#     plt.tight_layout()
#     plt.show()

# %%
import torch
import matplotlib.pyplot as plt

base = "/home/ir-rous1/rds/rds-ukaea-ap002-mOlK9qn0PlQ/ir-rous1/output/cnn-baseline/src/output/"

tasks = [
    "task_1-1", 
    "task_1-2", 
    "task_1-3",
    "task_2-1", 
    "task_2-2", 
    "task_2-3",
    "task_3-1", 
    "task_3-2", 
    "task_3-3"
    ]

model_versions = [
    "v2",
    "v3/run_1", 
    "v4/run_1"
    ]

list_lr = [
    # "00001", 
    "0001"
    ]

for task in tasks:

    plt.figure(figsize=(12, 5))

    print(task)

    for lr in list_lr:

        for model_version in model_versions:

            try: 
                data = torch.load(
                    base + f"cnn_model_b_8_w_32_lr_{lr}/{task}/model_{model_version}/training_history.pt",
                    map_location="cpu"
                )

                plt.plot(data["train_loss"], label=f"{model_version} train, lr={lr}")
                plt.plot(data["val_loss"], label=f"{model_version} val, lr={lr}")
                # plt.plot([ min(val, 100) for val in data["val_loss"] ], label=f"{model_version} val, lr={lr}")

                # plt.scatter([arr-1 for arr in data['epoch']], data["train_loss"], label=f"{model_version} train, lr={lr}")
                # plt.scatter([arr-1 for arr in data['epoch']], data["val_loss"], label=f"{model_version} val, lr={lr}")

                print('train ', task, model_version, lr, min(data["train_loss"]))
                print('val ', task, model_version, lr, min(data["val_loss"]))
            except: 
                continue
    
    for model_version in ["v4", 
                          "v5",
                          "v6", "v7", "v8"
                          ]:
         
        for model_v_path in [
            f"cnn_model_new_backbone_b_32_w_16_lr_0.0001_D_16/{task}/model_{model_version}/run_1/training_history.pt", 
            f"cnn_model_new_backbone_b_32_w_16_lr_0.0001_D_16/{task}/model_{model_version}/run_2/training_history.pt"]:
            
            # print(base + model_v_path)
            try:  
                data = torch.load(
                    base + model_v_path,
                    map_location="cpu"
                )

                plt.plot(data["train_loss"], label=f"{model_version} {model_v_path[23:47]} train")
                plt.plot(data["val_loss"], label=f"{model_version} {model_v_path[23:47]} val")

                # plt.scatter([arr-1 for arr in data['epoch']], data["train_loss"], label=f"{model_version} {model_v_path[23:47]} train")
                # plt.scatter([arr-1 for arr in data['epoch']], data["val_loss"], label=f"{model_version} {model_v_path[23:47]} val")

                print('train ', task, model_version, min(data["train_loss"]))
                print('val ', task, model_version, min(data["val_loss"]))
        
            except: 
                    print( "skipping model ", model_v_path )
                    continue

        for model_v_path in [
            f"cnn_model_new_backbone_b_32_w_8_lr_0.0001_D_16/{task}/model_{model_version}/run_1/training_history.pt",
            f"cnn_model_new_backbone_b_32_w_8_lr_0.0001_D_16/{task}/model_{model_version}/run_2/training_history.pt"
            ]:
            
            try:  
                data = torch.load(
                    base + model_v_path,
                    map_location="cpu"
                )

                plt.plot(data["train_loss"], label=f"{model_version} {model_v_path[23:47]} train")
                plt.plot(data["val_loss"], label=f"{model_version} {model_v_path[23:47]} val")
                
                # plt.scatter([arr-1 for arr in data['epoch']], data["train_loss"], label=f"{model_version} {model_v_path[23:47]} train")
                # plt.scatter([arr-1 for arr in data['epoch']], data["val_loss"], label=f"{model_version} {model_v_path[23:47]} val")

                print('train ', task, model_version, min(data["train_loss"]))
                print('val ', task, model_version, min(data["val_loss"]))
        
            except: 
                    print( "skipping model ", model_v_path )
                    continue
        
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# task_1-1
# skipping model  cnn_model_new_backbone_b_32_w_16_lr_0.0001_D_16/task_1-1/model_v4/run_1/training_history.pt
# skipping model  cnn_model_new_backbone_b_32_w_16_lr_0.0001_D_16/task_1-1/model_v4/run_2/training_history.pt
# skipping model  cnn_model_new_backbone_b_32_w_8_lr_0.0001_D_16/task_1-1/model_v4/run_1/training_history.pt
# skipping model  cnn_model_new_backbone_b_32_w_8_lr_0.0001_D_16/task_1-1/model_v4/run_2/training_history.pt
# skipping model  cnn_model_new_backbone_b_32_w_16_lr_0.0001_D_16/task_1-1/model_v5/run_1/training_history.pt
# skipping model  cnn_model_new_backbone_b_32_w_16_lr_0.0001_D_16/task_1-1/model_v5/run_2/training_history.pt
# skipping model  cnn_model_new_backbone_b_32_w_8_lr_0.0001_D_16/task_1-1/model_v5/run_1/training_history.pt
# skipping model  cnn_model_new_backbone_b_32_w_8_lr_0.0001_D_16/task_1-1/model_v5/run_2/training_history.pt
# skipping model  cnn_model_new_backbone_b_32_w_16_lr_0.0001_D_16/task_1-1/model_v6/run_1/training_history.pt
# ...

# %%
import torch
import matplotlib.pyplot as plt

base = "/home/ir-rous1/rds/rds-ukaea-ap002-mOlK9qn0PlQ/ir-rous1/output/cnn-baseline/src/output/"

tasks = [
    "task_1-1", 
    "task_1-2", 
    "task_1-3",
    "task_2-1", 
    "task_2-2", 
    "task_2-3",
    "task_3-1", 
    "task_3-2", 
    "task_3-3"
    ]

for task in tasks:

    plt.figure(figsize=(12, 5))

    print(task)

    for model_v_path in [
        f"cnn_model_new_backbone_b_32_w_8_lr_0.0001_D_16/{task}/model_{model_version}/run_1/training_history.pt",
        f"cnn_model_new_backbone_b_32_w_8_lr_0.0001_D_16/{task}/model_{model_version}/run_2/training_history.pt"
        ]:
        
        try:  
            data = torch.load(
                base + model_v_path,
                map_location="cpu"
            )

            plt.plot(data["train_loss"], label=f"{model_version} {model_v_path[23:47]} train")
            plt.plot(data["val_loss"], label=f"{model_version} {model_v_path[23:47]} val")
            
            # plt.scatter([arr-1 for arr in data['epoch']], data["train_loss"], label=f"{model_version} {model_v_path[23:47]} train")
            # plt.scatter([arr-1 for arr in data['epoch']], data["val_loss"], label=f"{model_version} {model_v_path[23:47]} val")

            print('train ', task, model_version, min(data["train_loss"]))
            print('val ', task, model_version, min(data["val_loss"]))
    
        except: 
                print( "skipping model ", model_v_path )
                continue
        
    for model_v_path in [
        f"../output_NEW/cnn_model_b_32_w_16_lr_0.0001_D_16/{task}/model_v5/run_1/training_history.pt",
        ]:
        
        try:  
            data = torch.load(
                base + model_v_path,
                map_location="cpu"
            )

            plt.plot(data["train_loss"], label=f"{model_v_path[23:47]} train v5 FINAL")
            plt.plot(data["val_loss"], label=f"{model_v_path[23:47]} val v5 FINAL")
            
            print('train ', task, 'v5 final', min(data["train_loss"]))
            print('val ', task, 'v5 final', min(data["val_loss"]))
    
        except: 
                print( "skipping model ", model_v_path )
                continue
        
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# task_1-1
# skipping model  cnn_model_new_backbone_b_32_w_8_lr_0.0001_D_16/task_1-1/model_v8/run_1/training_history.pt
# skipping model  cnn_model_new_backbone_b_32_w_8_lr_0.0001_D_16/task_1-1/model_v8/run_2/training_history.pt
# train  task_1-1 v5 final 1.4303701478152067
# val  task_1-1 v5 final 0.5376544349795387
# /tmp/ipykernel_3796627/2886518458.py:70: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# task_1-2
# skipping model  cnn_model_new_backbone_b_32_w_8_lr_0.0001_D_16/task_1-2/model_v8/run_1/training_history.pt
# skipping model  cnn_model_new_backbone_b_32_w_8_lr_0.0001_D_16/task_1-2/model_v8/run_2/training_history.pt
# train  task_1-2 v5 final 0.004431489043309794
# val  task_1-2 v5 final 0.0038771630047999507
# task_1-3
# skipping model  cnn_model_new_backbone_b_32_w_8_lr_0.0001_D_16/task_1-3/model_v8/run_1/training_history.pt
# ...

# %%
import torch
import matplotlib.pyplot as plt

base = "/home/ir-rous1/rds/rds-ukaea-ap002-mOlK9qn0PlQ/ir-rous1/output/cnn-baseline/src/output/"

tasks = [
    "task_1-1", 
    "task_1-2", 
    "task_1-3",
    "task_2-1", 
    "task_2-2", 
    "task_2-3",
    "task_3-1", 
    "task_3-2", 
    "task_3-3"
    ]

model_versions = [
    # "v2",
    # "v3/run_1", 
    # "v4/run_1"
    ]

list_lr = [
    # "00001", 
    "0001"
    ]

for task in tasks:

    plt.figure(figsize=(12, 5))

    print(task)

    for lr in list_lr:

        for model_version in model_versions:

            try: 
                data = torch.load(
                    base + f"cnn_model_b_8_w_32_lr_{lr}/{task}/model_{model_version}/training_history.pt",
                    map_location="cpu"
                )

                plt.plot(data["train_loss"], label=f"{model_version} train, lr={lr}")
                plt.plot(data["val_loss"], label=f"{model_version} val, lr={lr}")
                # plt.plot([ min(val, 100) for val in data["val_loss"] ], label=f"{model_version} val, lr={lr}")

                # plt.scatter([arr-1 for arr in data['epoch']], data["train_loss"], label=f"{model_version} train, lr={lr}")
                # plt.scatter([arr-1 for arr in data['epoch']], data["val_loss"], label=f"{model_version} val, lr={lr}")

                print('train ', task, model_version, lr, min(data["train_loss"]))
                print('val ', task, model_version, lr, min(data["val_loss"]))
            except: 
                continue
    
    for model_version in ["v4", 
                          "v5",
                          "v6", "v7", "v8"
                          ]:
         
        for model_v_path in [
            f"cnn_model_new_backbone_b_32_w_16_lr_0.0001_D_16/{task}/model_{model_version}/run_1/training_history.pt", 
            f"cnn_model_new_backbone_b_32_w_16_lr_0.0001_D_16/{task}/model_{model_version}/run_2/training_history.pt"]:
            
            # print(base + model_v_path)
            try:  
                data = torch.load(
                    base + model_v_path,
                    map_location="cpu"
                )

                plt.plot(data["train_loss"], label=f"{model_version} {model_v_path[23:47]} train")
                plt.plot(data["val_loss"], label=f"{model_version} {model_v_path[23:47]} val")

                # plt.scatter([arr-1 for arr in data['epoch']], data["train_loss"], label=f"{model_version} {model_v_path[23:47]} train")
                # plt.scatter([arr-1 for arr in data['epoch']], data["val_loss"], label=f"{model_version} {model_v_path[23:47]} val")

                print('train ', task, model_version, min(data["train_loss"]))
                print('val ', task, model_version, min(data["val_loss"]))
        
            except: 
                    print( "skipping model ", model_v_path )
                    continue

    for model_v_path in [
        f"cnn_model_new_backbone_b_32_w_8_lr_0.0001_D_16/{task}/model_{model_version}/run_1/training_history.pt",
        f"cnn_model_new_backbone_b_32_w_8_lr_0.0001_D_16/{task}/model_{model_version}/run_2/training_history.pt"
        ]:
        
        try:  
            data = torch.load(
                base + model_v_path,
                map_location="cpu"
            )

            plt.plot(data["train_loss"], label=f"{model_version} {model_v_path[23:47]} train")
            plt.plot(data["val_loss"], label=f"{model_version} {model_v_path[23:47]} val")
            
            # plt.scatter([arr-1 for arr in data['epoch']], data["train_loss"], label=f"{model_version} {model_v_path[23:47]} train")
            # plt.scatter([arr-1 for arr in data['epoch']], data["val_loss"], label=f"{model_version} {model_v_path[23:47]} val")

            print('train ', task, model_version, min(data["train_loss"]))
            print('val ', task, model_version, min(data["val_loss"]))
    
        except: 
                print( "skipping model ", model_v_path )
                continue
        
    for model_v_path in [
        f"../output_NEW/cnn_model_b_32_w_16_lr_0.0001_D_16/{task}/model_v5/run_1/training_history.pt",
        ]:
        
        try:  
            data = torch.load(
                base + model_v_path,
                map_location="cpu"
            )

            plt.plot(data["train_loss"], label="train v5 FINAL")
            plt.plot(data["val_loss"], label="val v5 FINAL")
            
            # plt.scatter([arr-1 for arr in data['epoch']], data["train_loss"], label=f"{model_version} {model_v_path[23:47]} train")
            # plt.scatter([arr-1 for arr in data['epoch']], data["val_loss"], label=f"{model_version} {model_v_path[23:47]} val")

            print('train ', task, 'v5 final', min(data["train_loss"]))
            print('val ', task, 'v5 final', min(data["val_loss"]))
    
        except: 
                print( "skipping model ", model_v_path )
                continue
        
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# task_1-1
# skipping model  cnn_model_new_backbone_b_32_w_16_lr_0.0001_D_16/task_1-1/model_v4/run_1/training_history.pt
# skipping model  cnn_model_new_backbone_b_32_w_16_lr_0.0001_D_16/task_1-1/model_v4/run_2/training_history.pt
# train  task_1-1 v5 1.4624039374056264
# val  task_1-1 v5 0.5584870635689562
# train  task_1-1 v5 3.3006292193891547
# val  task_1-1 v5 1.240872991511143
# skipping model  cnn_model_new_backbone_b_32_w_16_lr_0.0001_D_16/task_1-1/model_v6/run_1/training_history.pt
# skipping model  cnn_model_new_backbone_b_32_w_16_lr_0.0001_D_16/task_1-1/model_v6/run_2/training_history.pt
# skipping model  cnn_model_new_backbone_b_32_w_16_lr_0.0001_D_16/task_1-1/model_v7/run_1/training_history.pt
# skipping model  cnn_model_new_backbone_b_32_w_16_lr_0.0001_D_16/task_1-1/model_v7/run_2/training_history.pt
# skipping model  cnn_model_new_backbone_b_32_w_16_lr_0.0001_D_16/task_1-1/model_v8/run_1/training_history.pt
# ...

# %%
import torch
import matplotlib.pyplot as plt

base = "/home/ir-rous1/rds/rds-ukaea-ap002-mOlK9qn0PlQ/ir-rous1/output/cnn-baseline/src/output/"

plt.figure(figsize=(8, 5))

tasks = [
    "task_4-1", 
    "task_4-2", 
    "task_4-3",
    "task_4-4",
    # "task_4-5",
    ]

model_versions = [
    "v3", 
    "v4",
    # "v5",
    # "v6"
    ]

list_lr = ["00001"]

for task in tasks:

    print(task)

    for lr in list_lr:

        for model_version in model_versions:

            try: 
                data = torch.load(
                    base + f"cnn_model_b_8_w_4_lr_0.{lr}/{task}/model_{model_version}/run_1/training_history.pt",
                    map_location="cpu"
                )

                plt.plot(data["train_loss"], label=f"{model_version} train, lr={lr}")
                # plt.plot(data["val_loss"], label=f"{model_version} val, lr={lr}")

                # plt.plot([ min(val, 100) for val in data["val_loss"] ], label=f"{model_version} val, lr={lr}")

                plt.scatter([arr-1 for arr in data['epoch']], data["train_loss"], label=f"{model_version} train, lr={lr}")
                # plt.scatter([arr-1 for arr in data['epoch']], data["val_loss"], label=f"{model_version} val, lr={lr}")

                print('train ', task, model_version, lr, min(data["train_loss"]))
                print('val ', task, model_version, lr, min(data["val_loss"]))
            
            except:
                continue

            try: 
                data = torch.load(
                    base + f"cnn_model_b_16_w_4_lr_0.{lr}/{task}/model_{model_version}/run_1/training_history.pt",
                    map_location="cpu"
                )

                plt.plot(data["train_loss"], label=f"{model_version} train, lr={lr}")
                # plt.plot(data["val_loss"], label=f"{model_version} val, lr={lr}")

                # plt.plot([ min(val, 100) for val in data["val_loss"] ], label=f"{model_version} val, lr={lr}")

                plt.scatter([arr-1 for arr in data['epoch']], data["train_loss"], label=f"{model_version} train, lr={lr}")
                # plt.scatter([arr-1 for arr in data['epoch']], data["val_loss"], label=f"{model_version} val, lr={lr}")

                print('train ', task, model_version, lr, min(data["train_loss"]))
                print('val ', task, model_version, lr, min(data["val_loss"]))
            
            except:
                continue
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# task_4-1

# %%
#
